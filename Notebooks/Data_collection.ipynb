# %%
import pandas as pd

# %%
rape_victim_2018= pd.read_csv(r'Rape_analysis2018-2022\\NCRB_CII_2018_rape_victim.csv')
rape_victim_2019=pd.read_csv(r'Rape_analysis2018-2022\\NCRB_CII-2019_rape victim.csv')
rape_victim_2020= pd.read_csv(r'Rape_analysis2018-2022\\NCRB_2020_rape victim.csv')
rape_victim_2021=pd.read_csv(r'Rape_analysis2018-2022\\NCRB-2021_rape victim.csv')
rape_victim_2022=pd.read_csv(r'Rape_analysis2018-2022\\2022-state wise case.csv')

# %%
rape_victim_2018.shape
# Out:
# (40, 15)

# %%
rape_victim_2018.head(5)
# Out:
#   S. No (Col.1) Category (Col.2)   State/UT (Col.3)  Cases Reported (Col.4)  \
# 0             1            State     Andhra Pradesh                   971.0
# 1             2            State  Arunachal Pradesh                    67.0
# 2             3            State              Assam                  1648.0
# 3             4            State              Bihar                   651.0
# 4             5            State       Chhattisgarh                  2091.0
#
#    Child Victims of Rape (Below 18 Yrs) - Below 6 Years (Col.5)  \
# 0                                               16.0
# 1                                                4.0
# 2                                                7.0
# 3                                                0.0
# 4                                               41.0
#
#    Child Victims of Rape (Below 18 Yrs) - 6 Years & Above - Below 12 Years (Col.6)  \
# 0                                               57.0
# ...

# %%
rape_victim_2018.columns
# Out:
# Index(['S. No (Col.1)', 'Category (Col.2)', 'State/UT (Col.3)',
#        'Cases Reported (Col.4)',
#        'Child Victims of Rape (Below 18 Yrs) - Below 6 Years (Col.5)',
#        'Child Victims of Rape (Below 18 Yrs) - 6 Years & Above - Below 12 Years (Col.6)',
#        'Child Victims of Rape (Below 18 Yrs) - 12 Years & Above - Below 16 Years (Col.7)',
#        'Child Victims of Rape (Below 18 Yrs) - 16 Years & Above - Below 18 Years (Col.8)',
#        'Child Victims of Rape (Below 18 Yrs) - Total Girl/Child Victims (Col.9)',
#        'Women Victims of Rape (Above 18 Yrs) - 18 Years & Above - Below 30 Years (Col.10)',
#        'Women Victims of Rape (Above 18 Yrs) - 30 Years & Above - Below 45 Years (Col.11)',
#        'Women Victims of Rape (Above 18 Yrs) - 45 Years & Above - Below 60 Years (Col.12)',
#        'Women Victims of Rape (Above 18 Yrs) - 60 Years & Above (Col.13)',
#        'Women Victims of Rape (Above 18 Yrs) - Total Women/Adult Victims (Col.14)',
# ...

# %%
rape_victim_2019.shape
# Out:
# (40, 14)

# %%
rape_victim_2019.columns
# Out:
# Index(['Category', 'State/UT ', 'Cases Reported ',
#        'Child Victims of Rape (Below 18 Yrs) - Below 6 Years',
#        'Child Victims of Rape (Below 18 Yrs) - 6 Years & Above-Below 12 Years',
#        'Child Victims of Rape (Below 18 Yrs) - 12 Years & Above-Below 16 Years',
#        'Child Victims of Rape (Below 18 Yrs) - 16 Years & Above-Below 18 Years',
#        'Child Victims of Rape (Below 18 Yrs) - Total Girls /Child Victims',
#        'Women Victims of Rape (Above 18 Yrs) - 18 Years & Abov-Below 30 Years',
#        'Women Victims of Rape (Above 18 Yrs) - 30 Years & Above-Below 45 Years',
#        'Women Victims of Rape (Above 18 Yrs) - 45 Years & Above-Below 60 Years',
#        'Women Victims of Rape (Above 18 Yrs) - 60 Years & Above',
#        'Women Victims of Rape (Above 18 Yrs) - Total Women / Adult Victims',
#        'Total Victims'],
#       dtype='object')

# %%
rape_victim_2019.head(3)
# Out:
#   Category          State/UT   Cases Reported   \
# 0    State    Andhra Pradesh            1086.0
# 1    State  Arunachal Pradesh             63.0
# 2    State             Assam            1773.0
#
#    Child Victims of Rape (Below 18 Yrs) - Below 6 Years  \
# 0                                               16.0
# 1                                                1.0
# 2                                                0.0
#
#    Child Victims of Rape (Below 18 Yrs) - 6 Years & Above-Below 12 Years  \
# 0                                               38.0
# 1                                                2.0
# 2                                                7.0
#
#    Child Victims of Rape (Below 18 Yrs) - 12 Years & Above-Below 16 Years  \
# 0                                              184.0
# 1                                               13.0
# 2                                               50.0
#
#    Child Victims of Rape (Below 18 Yrs) - 16 Years & Above-Below 18 Years  \
# ...

# %%
rape_victim_2020.head(2)
# Out:
#   Si. No (Col. 1) Category   State/UT (Col. 2)  Cases Reported - (Col. 3)  \
# 0               1     State     Andhra Pradesh                     1095.0
# 1               2     State  Arunachal Pradesh                       60.0
#
#    Child Victims of Rape (Below 18 Yrs) - Below 6 Years - (Col. 4)  \
# 0                                               27.0
# 1                                                1.0
#
#    Child Victims of Rape (Below 18 Yrs) - 6 Years & Above - Below 12 Years - (Col. 5)  \
# 0                                               74.0
# 1                                                6.0
#
#    Child Victims of Rape (Below 18 Yrs) - 12 Years & Above - Below 16 Years - (Col. 6)  \
# 0                                              214.0
# 1                                               14.0
#
#    Child Victims of Rape (Below 18 Yrs) - 16 Years & Above - Below 18 Years - (Col. 7)  \
# 0                                              272.0
# ...

# %%
rape_victim_2020.columns
# Out:
# Index(['Si. No (Col. 1)', 'Category ', 'State/UT (Col. 2)',
#        'Cases Reported - (Col. 3)',
#        'Child Victims of Rape (Below 18 Yrs) - Below 6 Years - (Col. 4)',
#        'Child Victims of Rape (Below 18 Yrs) - 6 Years & Above - Below 12 Years - (Col. 5)',
#        'Child Victims of Rape (Below 18 Yrs) - 12 Years & Above - Below 16 Years - (Col. 6)',
#        'Child Victims of Rape (Below 18 Yrs) - 16 Years & Above - Below 18 Years - (Col. 7)',
#        'Child Victims of Rape (Below 18 Yrs) - Total Girl / Child Victims - (Col. 8)',
#        'Women Victims of Rape (Above 18 Years) - 18 Years & Above - Below 30 Years - (Col. 9)',
#        'Women Victims of Rape (Above 18 Years) - 30 Years & Above - Below 45 Years - (Col. 10)',
#        'Women Victims of Rape (Above 18 Years) - 45 Years & Above - Below 60 Years - (Col. 11)',
#        'Women Victims of Rape (Above 18 Years) - 60 Years & Above - (Col. 12)',
# ...

# %%
rape_victim_2020.shape
# Out:
# (40, 15)

# %%
rape_victim_2021.shape
# Out:
# (40, 14)

# %%
rape_victim_2021.columns
# Out:
# Index(['Sl. No. Col. (1)', 'State/UT Col. (2)', 'Cases Reported Col. (3)',
#        'Child Victims of Rape (Below 18 Yrs) - Below 6 Years - Col. (4)',
#        'Child Victims of Rape (Below 18 Yrs) - 6 Years & Above - Below 12 Years - Col. (5)',
#        'Child Victims of Rape (Below 18 Yrs) - 12 Years & Above - Below 16 Years - Col. (6)',
#        'Child Victims of Rape (Below 18 Yrs) - 16 Years & Above - Below 18 Years - Col. (7)',
#        'Child Victims of Rape (Below 18 Yrs) - Total Girl / Child Victims - Col. (8)',
#        'Women Victims of Rape (Above 18 Years) - 18 Years & Above - Below 30 Years - Col. (9)',
#        'Women Victims of Rape (Above 18 Years) - 30 Years & Above - Below 45 Years - Col. (10)',
#        'Women Victims of Rape (Above 18 Years) - 45 Years & Above - Below 60 Years - Col. (11)',
#        'Women Victims of Rape (Above 18 Years) - 60 Years & Above - Col. (12)',
#        'Women Victims of Rape (Above 18 Years) - Total Women / Adult Victims - Col. (13)',
# ...

# %%
rape_victim_2022.shape
# Out:
# (40, 14)

# %%
rape_victim_2022.columns
# Out:
# Index(['Sl. No.', 'State/UT', 'Cases Reported - Col.(3)',
#        'Child Victims of Rape (Below 18 Yrs) - Below 6 Years - Col.(4)',
#        'Child Victims of Rape (Below 18 Yrs) - 6 Years and Above - Below 12 Years - Col.(5)',
#        'Child Victims of Rape (Below 18 Yrs) - 12 Years and Above - Below 16 Years - Col.(6)',
#        'Child Victims of Rape (Below 18 Yrs) - 16 Years and Above - Below 18 Years - Col.(7)',
#        'Child Victims of Rape (Below 18 Yrs) - Total Girl / Child Victims - Col.(8)',
#        'Women Victims of Rape (Above 18 Years) - 18 Years and Above - Below 30 Years - Col.(9)',
#        'Women Victims of Rape (Above 18 Years) - 30 Years and Above - Below 45 Years - Col.(10)',
#        'Women Victims of Rape (Above 18 Years) - 45 Years and Above - Below 60 Years - Col.(11)',
#        'Women Victims of Rape (Above 18 Years) - 60 Years and Above - Col.(12)',
#        'Women Victims of Rape (Above 18 Years) - Total Women / Adult Victims - Col.(13)',
# ...

# %% [markdown]
# Kidnapping dataset

# %%
kidnapping_2018_2020=pd.read_csv(r'Kidnapping_2018_2022\NCRB2018-2020.csv')

# %%
kidnapping_Data2019_2021=pd.read_csv(r'Kidnapping_2018_2022\NCRb kidnapping 2019-2021.csv')

# %%
kidnapping_2020_2022=pd.read_csv(r'Kidnapping_2018_2022\kidnapping2021.csv')

# %%
kidnapping_2018_2020.head(1)
# Out:
#   SI. No.                 City  2018  2019  2020  \
# 0       1  Ahmedabad (Gujarat)   277   248   181
#
#    Actual Population (in Lakhs) (2011)  Rate of Kidnapping & Abduction (2020)  \
# 0                                 63.5                                    2.8
#
#    Chargesheeting Rate (2020)
# 0                        22.3

# %%
kidnapping_Data2019_2021.head(1)
# Out:
#   Sl. No.        State/UT   2019  2020  2021  \
# 0       1  Andhra Pradesh  902.0   737   835
#
#    Mid-Year Projected Population (in Lakhs) (2021)  \
# 0                                            528.5
#
#    Rate of Kidnapping & Abduction (2021)  Chargesheeting Rate (2021)
# 0                                    1.6                        71.8

# %%
kidnapping_2020_2022.head(1)
# Out:
#   Sl. No.        State/UT  2020  2021  2022  \
# 0       1  Andhra Pradesh   737   835   903
#
#    Mid-Year Projected Population (in Lakhs) (2022)  \
# 0                                            530.3
#
#    Rate of Kidnapping and Abduction (2022)  Chargesheeting Rate (2022)
# 0                                      1.7                        62.4

# %% [markdown]
# Population data

# %%
population=pd.read_csv('population.csv')

# %%
population.head(2)
# Out:
#            State  Population
# 0  Uttar Pradesh   199812341
# 1    Maharashtra   112374333

# %%
population.shape
# Out:
# (30, 2)
